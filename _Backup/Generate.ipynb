# %%
##pip install openai

# %%
import openai
import pandas as pd
import time

# %%
client = openai.OpenAI(api_key="Your key api here")

# %%
data = pd.read_csv("Preprocessed Data.csv")
data.head(5)
# Out:
#                                                 Text  \
# 0  Cá nhân đăng ký Bồi dưỡng nghiệp vụ đăng kiểm ...
# 1  Khi nào các tổ chức, cá nhân có thể gửi đề xuấ...
# 2  Điều kiện công nhận đối với TBKT công nghệ sin...
# 3  Cách thức thực hiện việc gửi đề xuất nhiệm vụ ...
# 4  Hồ sơ đề nghị thu hồi Giấy chứng nhận cơ sở đủ...
#
#                                                 Link  \
# 0  https://dichvucong.gov.vn/p/home/dvc-chi-tiet-...
# 1  https://dichvucong.gov.vn/p/home/dvc-chi-tiet-...
# 2  https://dichvucong.gov.vn/p/home/dvc-chi-tiet-...
# 3  https://dichvucong.gov.vn/p/home/dvc-chi-tiet-...
# 4  https://dichvucong.gov.vn/p/home/dvc-chi-tiet-...
#
#                                          Câu trả lời  \
# 0  Theo quy định tại Khoản 3, Điều 8 Thông tư số ...
# 1  Định kỳ hàng năm theo thông báo trên trang thô...
# 2  Theo Điều 6 Thông tư số 23/2010/TT-BNNPTNT ngà...
# 3  Đề xuất nhiệm vụ KHCN có thể gửi trực tiếp tại...
# 4  Theo quy định tại Khoản 4, Điều 54 của Nghị đị...
#
#                                                 TTHC  \
# 0  {'Tên': ['Cấp, cấp lại thẻ, dấu kỹ thuật đăng ...
# 1  {'Tên': ['Phê duyệt danh mục đề tài khoa học v...
# 2  {'Tên': ['Công nhận tiến bộ kỹ thuật công nghệ...
# 3  {'Tên': ['Phê duyệt danh mục đề tài khoa học v...
# 4  {'Tên': ['Cấp, cấp lại giấy chứng nhận cơ sở đ...
#
#                                  Ministry  \
# 0  Bộ Nông nghiệp và Phát triển nông thôn
# 1  Bộ Nông nghiệp và Phát triển nông thôn
# 2  Bộ Nông nghiệp và Phát triển nông thôn
# 3  Bộ Nông nghiệp và Phát triển nông thôn
# 4  Bộ Nông nghiệp và Phát triển nông thôn
#
#                                         Câu_hỏi_sạch  \
# 0  cá nhân đăng ký bồi dưỡng nghiệp vụ đăng kiểm ...
# 1  khi nào các tổ chức cá nhân có thể gửi đề xuất...
# 2  điều kiện công nhận đối với tbkt công nghệ sin...
# 3  cách thức thực hiện việc gửi đề xuất nhiệm vụ ...
# 4  hồ sơ đề nghị thu hồi giấy chứng nhận cơ sở đủ...
#
#                                     Câu_trả_lời_sạch  \
# 0  theo quy định tại khoản 3 điều 8 thông tư số 2...
# 1  định kỳ hàng năm theo thông báo trên trang thô...
# 2  theo điều 6 thông tư số 23/2010/tt bnnptnt ngà...
# 3  đề xuất nhiệm vụ khcn có thể gửi trực tiếp tại...
# 4  theo quy định tại khoản 4 điều 54 của nghị địn...
#
#                                             Tên_TTHC  \
# 0  ['Cấp, cấp lại thẻ, dấu kỹ thuật đăng kiểm viê...
# 1  ['Phê duyệt danh mục đề tài khoa học và công n...
# 2  ['Công nhận tiến bộ kỹ thuật công nghệ sinh học']
# 3  ['Phê duyệt danh mục đề tài khoa học và công n...
# 4  ['Cấp, cấp lại giấy chứng nhận cơ sở đủ điều k...
#
#                                Tên_cơ_quan_thực_hiện
# 0                    [['Cục Thủy sản - Bộ NN-PTNT']]
# 1          [['Vụ khoa học công nghệ và môi trường']]
# 2          [['Vụ khoa học công nghệ và môi trường']]
# 3          [['Vụ khoa học công nghệ và môi trường']]
# 4  [['Cơ quan quản lý nhà nước về thủy sản cấp tỉ...

# %%
data.shape[0]
# Out:
# 6861

# %%
instruction_0 = """Bạn sẽ đóng vai trò là một trình tạo câu trả lời sai (hallucinated answer generator). Với một câu hỏi, câu trả lời đúng và kiến thức liên quan, mục tiêu của bạn là viết một câu trả lời nghe có vẻ hợp lý nhưng thực tế lại sai.
Bạn PHẢI tạo ra câu trả lời sai bằng cách sau:
Hiểu sai ngữ cảnh (Misinterpretation): Bạn cố gắng trả lời nhưng lại hiểu sai ngữ cảnh và ý định của câu hỏi.
Bạn PHẢI ghi rõ nhãn loại sai **trước câu trả lời** theo định dạng sau:  
**[Hiểu sai ngữ cảnh]: Câu trả lời bịa đặt...**  
Chỉ trả lời theo yêu cầu mà không nhắc lại hướng dẫn hoặc lưu ý gì khác."""

instruction_1 = """Bạn sẽ đóng vai trò là một trình tạo câu trả lời sai (hallucinated answer generator). Với một câu hỏi, câu trả lời đúng và kiến thức liên quan, mục tiêu của bạn là viết một câu trả lời nghe có vẻ hợp lý nhưng thực tế lại sai.
Bạn PHẢI tạo ra câu trả lời sai bằng cách sau: 
Sai thông tin (Factual Contradiction): Câu trả lời có mâu thuẫn thực tế với kiến thức được cung cấp. Bạn có thể bịa ra một số thông tin không có trong dữ liệu gốc.
Bạn PHẢI ghi rõ nhãn loại sai **trước câu trả lời** theo định dạng sau:  
**[Sai thông tin]: Câu trả lời bịa đặt...**  
Chỉ trả lời theo yêu cầu mà không nhắc lại hướng dẫn hoặc lưu ý gì khác."""

instruction_2 = """Bạn sẽ đóng vai trò là một trình tạo câu trả lời sai (hallucinated answer generator). Với một câu hỏi, câu trả lời đúng và kiến thức liên quan, mục tiêu của bạn là viết một câu trả lời nghe có vẻ hợp lý nhưng thực tế lại sai.
Bạn PHẢI tạo ra câu trả lời sai bằng cách sau:
Quá chung hoặc quá cụ thể (Specificity Error): Câu trả lời quá chung chung hoặc quá chi tiết so với mức độ phù hợp của câu hỏi.
Bạn PHẢI ghi rõ nhãn loại sai **trước câu trả lời** theo định dạng sau:  
**[Quá chung hoặc quá cụ thể]: Câu trả lời bịa đặt...**  
Chỉ trả lời theo yêu cầu mà không nhắc lại hướng dẫn hoặc lưu ý gì khác."""

instruction_3 = """Bạn sẽ đóng vai trò là một trình tạo câu trả lời sai (hallucinated answer generator). Với một câu hỏi, câu trả lời đúng và kiến thức liên quan, mục tiêu của bạn là viết một câu trả lời nghe có vẻ hợp lý nhưng thực tế lại sai.
Bạn PHẢI tạo ra câu trả lời sai bằng cách sau:
Lập luận sai (Incorrect Reasoning): Bạn suy luận từ kiến thức nhưng đi đến một kết luận sai, không thể suy ra từ dữ liệu ban đầu.
Bạn PHẢI ghi rõ nhãn loại sai **trước câu trả lời** theo định dạng sau:  
**[Lập luận sai]: Câu trả lời bịa đặt...**  
Chỉ trả lời theo yêu cầu mà không nhắc lại hướng dẫn hoặc lưu ý gì khác."""

# %%
def get_qa_res(topic, question, answer, instruction):
    if isinstance(instruction, str):
        message = [
            {"role": "system", "content": instruction},  
            {"role": 
             "user", "content":
                                "\n\n#Chủ đề#: " + topic +
                                "\n#Câu hỏi#: " + question +
                                "\n#Câu trả lời đúng#: " + answer +
                                "\n#Câu trả lời bịa đặt#: "}
        ]
    else:
        raise TypeError("The instruction must be str or list!")
             
    while True:
        try:
            res = client.chat.completions.create(
                model="gpt-4o-mini",
                messages=message,
                temperature=1,
                max_tokens=4000,
                top_p=1
            )
            break
        except openai.error.RateLimitError:
            print('openai.error.RateLimitError\nRetrying...')
            time.sleep(60)
        except openai.error.ServiceUnavailableError:
            print('openai.error.ServiceUnavailableError\nRetrying...')
            time.sleep(20)
        except openai.error.Timeout:
            print('openai.error.Timeout\nRetrying...')
            time.sleep(20)
        except openai.error.APIError:
            print('openai.error.APIError\nRetrying...')
            time.sleep(20)
        except openai.error.APIConnectionError:
            print('openai.error.APIConnectionError\nRetrying...')
            time.sleep(20)
    
    
    return res.choices[0].message.content

# %%
new_data = {"Chủ đề": [], "Câu hỏi": [], "Câu trả lời đúng": [], "Câu trả lời bịa đặt": []}
def generate_qa_dataset(data, instruction_0, instruction_1, instruction_2, instruction_3):
    for i in range(6000,data.shape[0]):

        question = data.iloc[i]['Text']
        answer = data.iloc[i]['Câu trả lời']
        topic = data.iloc[i]['Ministry']
        if i%4 == 0:
            ans = get_qa_res(topic, question, answer, instruction_0)
        elif i%4 == 1:
            ans = get_qa_res(topic, question, answer, instruction_1)
        elif i%4 == 2:
            ans = get_qa_res(topic, question, answer, instruction_2)
        else:
            ans = get_qa_res(topic, question, answer, instruction_3)
        new_data["Chủ đề"].append(topic)
        new_data["Câu hỏi"].append(question)
        new_data["Câu trả lời đúng"].append(answer)
        new_data["Câu trả lời bịa đặt"].append(ans)
        print(" sample {} completed!".format(i))

# %%
generate_qa_dataset(data, instruction_0, instruction_1, instruction_2, instruction_3)
# Out:
#  sample 6000 completed!
#  sample 6001 completed!
#  sample 6002 completed!
#  sample 6003 completed!
#  sample 6004 completed!
#  sample 6005 completed!
#  sample 6006 completed!
#  sample 6007 completed!
#  sample 6008 completed!
#  sample 6009 completed!
#  sample 6010 completed!
#  sample 6011 completed!
#  sample 6012 completed!
#  sample 6013 completed!
#  sample 6014 completed!
#  sample 6015 completed!
#  sample 6016 completed!
#  sample 6017 completed!
#  sample 6018 completed!
#  sample 6019 completed!
#  sample 6020 completed!
#  sample 6021 completed!
#  sample 6022 completed!
#  sample 6023 completed!
#  sample 6024 completed!
#  sample 6025 completed!
#  sample 6026 completed!
#  sample 6027 completed!
#  sample 6028 completed!
#  sample 6029 completed!
#  sample 6030 completed!
#  sample 6031 completed!
#  sample 6032 completed!
#  sample 6033 completed!
#  sample 6034 completed!
#  sample 6035 completed!
#  sample 6036 completed!
#  sample 6037 completed!
#  sample 6038 completed!
#  sample 6039 completed!
#  sample 6040 completed!
#  sample 6041 completed!
#  sample 6042 completed!
#  sample 6043 completed!
#  sample 6044 completed!
#  sample 6045 completed!
#  sample 6046 completed!
#  sample 6047 completed!
#  sample 6048 completed!
#  sample 6049 completed!
#  sample 6050 completed!
#  sample 6051 completed!
#  sample 6052 completed!
#  sample 6053 completed!
#  sample 6054 completed!
#  sample 6055 completed!
#  sample 6056 completed!
#  sample 6057 completed!
#  sample 6058 completed!
#  sample 6059 completed!
#  sample 6060 completed!
#  sample 6061 completed!
#  sample 6062 completed!
#  sample 6063 completed!
#  sample 6064 completed!
#  sample 6065 completed!
#  sample 6066 completed!
#  sample 6067 completed!
#  sample 6068 completed!
#  sample 6069 completed!
#  sample 6070 completed!
#  sample 6071 completed!
#  sample 6072 completed!
#  sample 6073 completed!
#  sample 6074 completed!
#  sample 6075 completed!
#  sample 6076 completed!
#  sample 6077 completed!
#  sample 6078 completed!
#  sample 6079 completed!
#  sample 6080 completed!
#  sample 6081 completed!
#  sample 6082 completed!
#  sample 6083 completed!
#  sample 6084 completed!
#  sample 6085 completed!
#  sample 6086 completed!
#  sample 6087 completed!
#  sample 6088 completed!
#  sample 6089 completed!
#  sample 6090 completed!
#  sample 6091 completed!
#  sample 6092 completed!
#  sample 6093 completed!
#  sample 6094 completed!
#  sample 6095 completed!
#  sample 6096 completed!
#  sample 6097 completed!
#  sample 6098 completed!
#  sample 6099 completed!
#  sample 6100 completed!
#  sample 6101 completed!
#  sample 6102 completed!
#  sample 6103 completed!
#  sample 6104 completed!
#  sample 6105 completed!
#  sample 6106 completed!
#  sample 6107 completed!
#  sample 6108 completed!
#  sample 6109 completed!
#  sample 6110 completed!
#  sample 6111 completed!
#  sample 6112 completed!
#  sample 6113 completed!
#  sample 6114 completed!
#  sample 6115 completed!
#  sample 6116 completed!
#  sample 6117 completed!
#  sample 6118 completed!
#  sample 6119 completed!
#  sample 6120 completed!
#  sample 6121 completed!
#  sample 6122 completed!
#  sample 6123 completed!
#  sample 6124 completed!
#  sample 6125 completed!
#  sample 6126 completed!
#  sample 6127 completed!
#  sample 6128 completed!
#  sample 6129 completed!
#  sample 6130 completed!
#  sample 6131 completed!
#  sample 6132 completed!
#  sample 6133 completed!
#  sample 6134 completed!
#  sample 6135 completed!
#  sample 6136 completed!
#  sample 6137 completed!
#  sample 6138 completed!
#  sample 6139 completed!
#  sample 6140 completed!
#  sample 6141 completed!
#  sample 6142 completed!
#  sample 6143 completed!
#  sample 6144 completed!
#  sample 6145 completed!
#  sample 6146 completed!
#  sample 6147 completed!
#  sample 6148 completed!
#  sample 6149 completed!
#  sample 6150 completed!
#  sample 6151 completed!
#  sample 6152 completed!
#  sample 6153 completed!
#  sample 6154 completed!
#  sample 6155 completed!
#  sample 6156 completed!
#  sample 6157 completed!
#  sample 6158 completed!
#  sample 6159 completed!
#  sample 6160 completed!
#  sample 6161 completed!
#  sample 6162 completed!
#  sample 6163 completed!
#  sample 6164 completed!
#  sample 6165 completed!
#  sample 6166 completed!
#  sample 6167 completed!
#  sample 6168 completed!
#  sample 6169 completed!
#  sample 6170 completed!
#  sample 6171 completed!
#  sample 6172 completed!
#  sample 6173 completed!
#  sample 6174 completed!
#  sample 6175 completed!
#  sample 6176 completed!
#  sample 6177 completed!
#  sample 6178 completed!
#  sample 6179 completed!
#  sample 6180 completed!
#  sample 6181 completed!
#  sample 6182 completed!
#  sample 6183 completed!
#  sample 6184 completed!
#  sample 6185 completed!
#  sample 6186 completed!
#  sample 6187 completed!
#  sample 6188 completed!
#  sample 6189 completed!
#  sample 6190 completed!
#  sample 6191 completed!
#  sample 6192 completed!
#  sample 6193 completed!
#  sample 6194 completed!
#  sample 6195 completed!
#  sample 6196 completed!
#  sample 6197 completed!
#  sample 6198 completed!
#  sample 6199 completed!
#  sample 6200 completed!
#  sample 6201 completed!
#  sample 6202 completed!
#  sample 6203 completed!
#  sample 6204 completed!
#  sample 6205 completed!
#  sample 6206 completed!
#  sample 6207 completed!
#  sample 6208 completed!
#  sample 6209 completed!
#  sample 6210 completed!
#  sample 6211 completed!
#  sample 6212 completed!
#  sample 6213 completed!
#  sample 6214 completed!
#  sample 6215 completed!
#  sample 6216 completed!
#  sample 6217 completed!
#  sample 6218 completed!
#  sample 6219 completed!
#  sample 6220 completed!
#  sample 6221 completed!
#  sample 6222 completed!
#  sample 6223 completed!
#  sample 6224 completed!
#  sample 6225 completed!
#  sample 6226 completed!
#  sample 6227 completed!
#  sample 6228 completed!
#  sample 6229 completed!
#  sample 6230 completed!
#  sample 6231 completed!
#  sample 6232 completed!
#  sample 6233 completed!
#  sample 6234 completed!
#  sample 6235 completed!
#  sample 6236 completed!
#  sample 6237 completed!
#  sample 6238 completed!
#  sample 6239 completed!
#  sample 6240 completed!
#  sample 6241 completed!
#  sample 6242 completed!
#  sample 6243 completed!
#  sample 6244 completed!
#  sample 6245 completed!
#  sample 6246 completed!
#  sample 6247 completed!
#  sample 6248 completed!
#  sample 6249 completed!
#  sample 6250 completed!
#  sample 6251 completed!
#  sample 6252 completed!
#  sample 6253 completed!
#  sample 6254 completed!
#  sample 6255 completed!
#  sample 6256 completed!
#  sample 6257 completed!
#  sample 6258 completed!
#  sample 6259 completed!
#  sample 6260 completed!
#  sample 6261 completed!
#  sample 6262 completed!
#  sample 6263 completed!
#  sample 6264 completed!
#  sample 6265 completed!
#  sample 6266 completed!
#  sample 6267 completed!
#  sample 6268 completed!
#  sample 6269 completed!
#  sample 6270 completed!
#  sample 6271 completed!
#  sample 6272 completed!
#  sample 6273 completed!
#  sample 6274 completed!
#  sample 6275 completed!
#  sample 6276 completed!
#  sample 6277 completed!
#  sample 6278 completed!
#  sample 6279 completed!
#  sample 6280 completed!
#  sample 6281 completed!
#  sample 6282 completed!
#  sample 6283 completed!
#  sample 6284 completed!
#  sample 6285 completed!
#  sample 6286 completed!
#  sample 6287 completed!
#  sample 6288 completed!
#  sample 6289 completed!
#  sample 6290 completed!
#  sample 6291 completed!
#  sample 6292 completed!
#  sample 6293 completed!
#  sample 6294 completed!
#  sample 6295 completed!
#  sample 6296 completed!
#  sample 6297 completed!
#  sample 6298 completed!
#  sample 6299 completed!
#  sample 6300 completed!
#  sample 6301 completed!
#  sample 6302 completed!
#  sample 6303 completed!
#  sample 6304 completed!
#  sample 6305 completed!
#  sample 6306 completed!
#  sample 6307 completed!
#  sample 6308 completed!
#  sample 6309 completed!
#  sample 6310 completed!
#  sample 6311 completed!
#  sample 6312 completed!
#  sample 6313 completed!
#  sample 6314 completed!
#  sample 6315 completed!
#  sample 6316 completed!
#  sample 6317 completed!
#  sample 6318 completed!
#  sample 6319 completed!
#  sample 6320 completed!
#  sample 6321 completed!
#  sample 6322 completed!
#  sample 6323 completed!
#  sample 6324 completed!
#  sample 6325 completed!
#  sample 6326 completed!
#  sample 6327 completed!
#  sample 6328 completed!
#  sample 6329 completed!
#  sample 6330 completed!
#  sample 6331 completed!
#  sample 6332 completed!
#  sample 6333 completed!
#  sample 6334 completed!
#  sample 6335 completed!
#  sample 6336 completed!
#  sample 6337 completed!
#  sample 6338 completed!
#  sample 6339 completed!
#  sample 6340 completed!
#  sample 6341 completed!
#  sample 6342 completed!
#  sample 6343 completed!
#  sample 6344 completed!
#  sample 6345 completed!
#  sample 6346 completed!
#  sample 6347 completed!
#  sample 6348 completed!
#  sample 6349 completed!
#  sample 6350 completed!
#  sample 6351 completed!
#  sample 6352 completed!
#  sample 6353 completed!
#  sample 6354 completed!
#  sample 6355 completed!
#  sample 6356 completed!
#  sample 6357 completed!
#  sample 6358 completed!
#  sample 6359 completed!
#  sample 6360 completed!
#  sample 6361 completed!
#  sample 6362 completed!
#  sample 6363 completed!
#  sample 6364 completed!
#  sample 6365 completed!
#  sample 6366 completed!
#  sample 6367 completed!
#  sample 6368 completed!
#  sample 6369 completed!
#  sample 6370 completed!
#  sample 6371 completed!
#  sample 6372 completed!
#  sample 6373 completed!
#  sample 6374 completed!
#  sample 6375 completed!
#  sample 6376 completed!
#  sample 6377 completed!
#  sample 6378 completed!
#  sample 6379 completed!
#  sample 6380 completed!
#  sample 6381 completed!
#  sample 6382 completed!
#  sample 6383 completed!
#  sample 6384 completed!
#  sample 6385 completed!
#  sample 6386 completed!
#  sample 6387 completed!
#  sample 6388 completed!
#  sample 6389 completed!
#  sample 6390 completed!
#  sample 6391 completed!
#  sample 6392 completed!
#  sample 6393 completed!
#  sample 6394 completed!
#  sample 6395 completed!
#  sample 6396 completed!
#  sample 6397 completed!
#  sample 6398 completed!
#  sample 6399 completed!
#  sample 6400 completed!
#  sample 6401 completed!
#  sample 6402 completed!
#  sample 6403 completed!
#  sample 6404 completed!
#  sample 6405 completed!
#  sample 6406 completed!
#  sample 6407 completed!
#  sample 6408 completed!
#  sample 6409 completed!
#  sample 6410 completed!
#  sample 6411 completed!
#  sample 6412 completed!
#  sample 6413 completed!
#  sample 6414 completed!
#  sample 6415 completed!
#  sample 6416 completed!
#  sample 6417 completed!
#  sample 6418 completed!
#  sample 6419 completed!
#  sample 6420 completed!
#  sample 6421 completed!
#  sample 6422 completed!
#  sample 6423 completed!
#  sample 6424 completed!
#  sample 6425 completed!
#  sample 6426 completed!
#  sample 6427 completed!
#  sample 6428 completed!
#  sample 6429 completed!
#  sample 6430 completed!
#  sample 6431 completed!
#  sample 6432 completed!
#  sample 6433 completed!
#  sample 6434 completed!
#  sample 6435 completed!
#  sample 6436 completed!
#  sample 6437 completed!
#  sample 6438 completed!
#  sample 6439 completed!
#  sample 6440 completed!
#  sample 6441 completed!
#  sample 6442 completed!
#  sample 6443 completed!
#  sample 6444 completed!
#  sample 6445 completed!
#  sample 6446 completed!
#  sample 6447 completed!
#  sample 6448 completed!
#  sample 6449 completed!
#  sample 6450 completed!
#  sample 6451 completed!
#  sample 6452 completed!
#  sample 6453 completed!
#  sample 6454 completed!
#  sample 6455 completed!
#  sample 6456 completed!
#  sample 6457 completed!
#  sample 6458 completed!
#  sample 6459 completed!
#  sample 6460 completed!
#  sample 6461 completed!
#  sample 6462 completed!
#  sample 6463 completed!
#  sample 6464 completed!
#  sample 6465 completed!
#  sample 6466 completed!
#  sample 6467 completed!
#  sample 6468 completed!
#  sample 6469 completed!
#  sample 6470 completed!
#  sample 6471 completed!
#  sample 6472 completed!
#  sample 6473 completed!
#  sample 6474 completed!
#  sample 6475 completed!
#  sample 6476 completed!
#  sample 6477 completed!
#  sample 6478 completed!
#  sample 6479 completed!
#  sample 6480 completed!
#  sample 6481 completed!
#  sample 6482 completed!
#  sample 6483 completed!
#  sample 6484 completed!
#  sample 6485 completed!
#  sample 6486 completed!
#  sample 6487 completed!
#  sample 6488 completed!
#  sample 6489 completed!
#  sample 6490 completed!
#  sample 6491 completed!
#  sample 6492 completed!
#  sample 6493 completed!
#  sample 6494 completed!
#  sample 6495 completed!
#  sample 6496 completed!
#  sample 6497 completed!
#  sample 6498 completed!
#  sample 6499 completed!
#  sample 6500 completed!
#  sample 6501 completed!
#  sample 6502 completed!
#  sample 6503 completed!
#  sample 6504 completed!
#  sample 6505 completed!
#  sample 6506 completed!
#  sample 6507 completed!
#  sample 6508 completed!
#  sample 6509 completed!
#  sample 6510 completed!
#  sample 6511 completed!
#  sample 6512 completed!
#  sample 6513 completed!
#  sample 6514 completed!
#  sample 6515 completed!
#  sample 6516 completed!
#  sample 6517 completed!
#  sample 6518 completed!
#  sample 6519 completed!
#  sample 6520 completed!
#  sample 6521 completed!
#  sample 6522 completed!
#  sample 6523 completed!
#  sample 6524 completed!
#  sample 6525 completed!
#  sample 6526 completed!
#  sample 6527 completed!
#  sample 6528 completed!
#  sample 6529 completed!
#  sample 6530 completed!
#  sample 6531 completed!
#  sample 6532 completed!
#  sample 6533 completed!
#  sample 6534 completed!
#  sample 6535 completed!
#  sample 6536 completed!
#  sample 6537 completed!
#  sample 6538 completed!
#  sample 6539 completed!
#  sample 6540 completed!
#  sample 6541 completed!
#  sample 6542 completed!
#  sample 6543 completed!
#  sample 6544 completed!
#  sample 6545 completed!
#  sample 6546 completed!
#  sample 6547 completed!
#  sample 6548 completed!
#  sample 6549 completed!
#  sample 6550 completed!
#  sample 6551 completed!
#  sample 6552 completed!
#  sample 6553 completed!
#  sample 6554 completed!
#  sample 6555 completed!
#  sample 6556 completed!
#  sample 6557 completed!
#  sample 6558 completed!
#  sample 6559 completed!
#  sample 6560 completed!
#  sample 6561 completed!
#  sample 6562 completed!
#  sample 6563 completed!
#  sample 6564 completed!
#  sample 6565 completed!
#  sample 6566 completed!
#  sample 6567 completed!
#  sample 6568 completed!
#  sample 6569 completed!
#  sample 6570 completed!
#  sample 6571 completed!
#  sample 6572 completed!
#  sample 6573 completed!
#  sample 6574 completed!
#  sample 6575 completed!
#  sample 6576 completed!
#  sample 6577 completed!
#  sample 6578 completed!
#  sample 6579 completed!
#  sample 6580 completed!
#  sample 6581 completed!
#  sample 6582 completed!
#  sample 6583 completed!
#  sample 6584 completed!
#  sample 6585 completed!
#  sample 6586 completed!
#  sample 6587 completed!
#  sample 6588 completed!
#  sample 6589 completed!
#  sample 6590 completed!
#  sample 6591 completed!
#  sample 6592 completed!
#  sample 6593 completed!
#  sample 6594 completed!
#  sample 6595 completed!
#  sample 6596 completed!
#  sample 6597 completed!
#  sample 6598 completed!
#  sample 6599 completed!
#  sample 6600 completed!
#  sample 6601 completed!
#  sample 6602 completed!
#  sample 6603 completed!
#  sample 6604 completed!
#  sample 6605 completed!
#  sample 6606 completed!
#  sample 6607 completed!
#  sample 6608 completed!
#  sample 6609 completed!
#  sample 6610 completed!
#  sample 6611 completed!
#  sample 6612 completed!
#  sample 6613 completed!
#  sample 6614 completed!
#  sample 6615 completed!
#  sample 6616 completed!
#  sample 6617 completed!
#  sample 6618 completed!
#  sample 6619 completed!
#  sample 6620 completed!
#  sample 6621 completed!
#  sample 6622 completed!
#  sample 6623 completed!
#  sample 6624 completed!
#  sample 6625 completed!
#  sample 6626 completed!
#  sample 6627 completed!
#  sample 6628 completed!
#  sample 6629 completed!
#  sample 6630 completed!
#  sample 6631 completed!
#  sample 6632 completed!
#  sample 6633 completed!
#  sample 6634 completed!
#  sample 6635 completed!
#  sample 6636 completed!
#  sample 6637 completed!
#  sample 6638 completed!
#  sample 6639 completed!
#  sample 6640 completed!
#  sample 6641 completed!
#  sample 6642 completed!
#  sample 6643 completed!
#  sample 6644 completed!
#  sample 6645 completed!
#  sample 6646 completed!
#  sample 6647 completed!
#  sample 6648 completed!
#  sample 6649 completed!
#  sample 6650 completed!
#  sample 6651 completed!
#  sample 6652 completed!
#  sample 6653 completed!
#  sample 6654 completed!
#  sample 6655 completed!
#  sample 6656 completed!
#  sample 6657 completed!
#  sample 6658 completed!
#  sample 6659 completed!
#  sample 6660 completed!
#  sample 6661 completed!
#  sample 6662 completed!
#  sample 6663 completed!
#  sample 6664 completed!
#  sample 6665 completed!
#  sample 6666 completed!
#  sample 6667 completed!
#  sample 6668 completed!
#  sample 6669 completed!
#  sample 6670 completed!
#  sample 6671 completed!
#  sample 6672 completed!
#  sample 6673 completed!
#  sample 6674 completed!
#  sample 6675 completed!
#  sample 6676 completed!
#  sample 6677 completed!
#  sample 6678 completed!
#  sample 6679 completed!
#  sample 6680 completed!
#  sample 6681 completed!
#  sample 6682 completed!
#  sample 6683 completed!
#  sample 6684 completed!
#  sample 6685 completed!
#  sample 6686 completed!
#  sample 6687 completed!
#  sample 6688 completed!
#  sample 6689 completed!
#  sample 6690 completed!
#  sample 6691 completed!
#  sample 6692 completed!
#  sample 6693 completed!
#  sample 6694 completed!
#  sample 6695 completed!
#  sample 6696 completed!
#  sample 6697 completed!
#  sample 6698 completed!
#  sample 6699 completed!
#  sample 6700 completed!
#  sample 6701 completed!
#  sample 6702 completed!
#  sample 6703 completed!
#  sample 6704 completed!
#  sample 6705 completed!
#  sample 6706 completed!
#  sample 6707 completed!
#  sample 6708 completed!
#  sample 6709 completed!
#  sample 6710 completed!
#  sample 6711 completed!
#  sample 6712 completed!
#  sample 6713 completed!
#  sample 6714 completed!
#  sample 6715 completed!
#  sample 6716 completed!
#  sample 6717 completed!
#  sample 6718 completed!
#  sample 6719 completed!
#  sample 6720 completed!
#  sample 6721 completed!
#  sample 6722 completed!
#  sample 6723 completed!
#  sample 6724 completed!
#  sample 6725 completed!
#  sample 6726 completed!
#  sample 6727 completed!
#  sample 6728 completed!
#  sample 6729 completed!
#  sample 6730 completed!
#  sample 6731 completed!
#  sample 6732 completed!
#  sample 6733 completed!
#  sample 6734 completed!
#  sample 6735 completed!
#  sample 6736 completed!
#  sample 6737 completed!
#  sample 6738 completed!
#  sample 6739 completed!
#  sample 6740 completed!
#  sample 6741 completed!
#  sample 6742 completed!
#  sample 6743 completed!
#  sample 6744 completed!
#  sample 6745 completed!
#  sample 6746 completed!
#  sample 6747 completed!
#  sample 6748 completed!
#  sample 6749 completed!
#  sample 6750 completed!
#  sample 6751 completed!
#  sample 6752 completed!
#  sample 6753 completed!
#  sample 6754 completed!
#  sample 6755 completed!
#  sample 6756 completed!
#  sample 6757 completed!
#  sample 6758 completed!
#  sample 6759 completed!
#  sample 6760 completed!
#  sample 6761 completed!
#  sample 6762 completed!
#  sample 6763 completed!
#  sample 6764 completed!
#  sample 6765 completed!
#  sample 6766 completed!
#  sample 6767 completed!
#  sample 6768 completed!
#  sample 6769 completed!
#  sample 6770 completed!
#  sample 6771 completed!
#  sample 6772 completed!
#  sample 6773 completed!
#  sample 6774 completed!
#  sample 6775 completed!
#  sample 6776 completed!
#  sample 6777 completed!
#  sample 6778 completed!
#  sample 6779 completed!
#  sample 6780 completed!
#  sample 6781 completed!
#  sample 6782 completed!
#  sample 6783 completed!
#  sample 6784 completed!
#  sample 6785 completed!
#  sample 6786 completed!
#  sample 6787 completed!
#  sample 6788 completed!
#  sample 6789 completed!
#  sample 6790 completed!
#  sample 6791 completed!
#  sample 6792 completed!
#  sample 6793 completed!
#  sample 6794 completed!
#  sample 6795 completed!
#  sample 6796 completed!
#  sample 6797 completed!
#  sample 6798 completed!
#  sample 6799 completed!
#  sample 6800 completed!
#  sample 6801 completed!
#  sample 6802 completed!
#  sample 6803 completed!
#  sample 6804 completed!
#  sample 6805 completed!
#  sample 6806 completed!
#  sample 6807 completed!
#  sample 6808 completed!
#  sample 6809 completed!
#  sample 6810 completed!
#  sample 6811 completed!
#  sample 6812 completed!
#  sample 6813 completed!
#  sample 6814 completed!
#  sample 6815 completed!
#  sample 6816 completed!
#  sample 6817 completed!
#  sample 6818 completed!
#  sample 6819 completed!
#  sample 6820 completed!
#  sample 6821 completed!
#  sample 6822 completed!
#  sample 6823 completed!
#  sample 6824 completed!
#  sample 6825 completed!
#  sample 6826 completed!
#  sample 6827 completed!
#  sample 6828 completed!
#  sample 6829 completed!
#  sample 6830 completed!
#  sample 6831 completed!
#  sample 6832 completed!
#  sample 6833 completed!
#  sample 6834 completed!
#  sample 6835 completed!
#  sample 6836 completed!
#  sample 6837 completed!
#  sample 6838 completed!
#  sample 6839 completed!
#  sample 6840 completed!
#  sample 6841 completed!
#  sample 6842 completed!
#  sample 6843 completed!
#  sample 6844 completed!
#  sample 6845 completed!
#  sample 6846 completed!
#  sample 6847 completed!
#  sample 6848 completed!
#  sample 6849 completed!
#  sample 6850 completed!
#  sample 6851 completed!
#  sample 6852 completed!
#  sample 6853 completed!
#  sample 6854 completed!
#  sample 6855 completed!
#  sample 6856 completed!
#  sample 6857 completed!
#  sample 6858 completed!
#  sample 6859 completed!
#  sample 6860 completed!

# %%
new_data_df = pd.DataFrame(new_data)
new_data_df.to_csv("Generated Data 7.csv", index=False, encoding='utf-8-sig')

# %%
import json

# %%
#tach new_data thanh json co key la cac cot
json_data = json.dumps([dict(zip(new_data.keys(), values)) for values in zip(*new_data.values())], ensure_ascii=False, indent=4)
with open('Generated Data 7.json', 'w', encoding='utf-8') as f:
    f.write(json_data)

# %%
# gop tat ca cac file 1-> 7 json lai thanh 1 generate_data.json va csv lại thanh generate_data.csv
#import os
#import json
#import pandas as pd

#data = []
#for file in os.listdir():
    #if file.startswith('Generated Data') and file.endswith('.json'):
        #with open(file, 'r', encoding='utf-8') as f:
            #data.extend(json.load(f))

#with open('Generated_data.json', 'w', encoding='utf-8') as f:
    #json.dump(data, f, ensure_ascii=False, indent=4)

#df = pd.DataFrame(data)
#df.to_csv('Generated_data.csv', index=False, encoding='utf-8-sig')

# %%
#import tiktoken

# %% [markdown]
# Caculate max answer token

# %%
#encoding = tiktoken.encoding_for_model("gpt-4o-mini")

# %%
#max_token_answer = 0
#indexmax = 0
#for i in range(data.shape[0]):
    #answer_token = encoding.encode(data.iloc[i]['Câu trả lời'])
    #max_token_answer = max(max_token_answer, len(answer_token))
    #indexmax = i
    #if max_token_answer == len(answer_token):
        #print("Max token answer: ", max_token_answer)
        #print("Index: ", indexmax)
#max_token_answer
